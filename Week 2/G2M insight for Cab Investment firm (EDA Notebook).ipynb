# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ### Load DataSets

# %%
# Find the current working directory and the datasets directory.
current_working_directory = os.getcwd()

datasets_directory = current_working_directory + "\DataSets"

# %% [markdown]
# First we can see some basic information on every data frame

# %%
# Load my csv data to a data frame.
cab_data_df = pd.read_csv(datasets_directory + '\Cab_Data.csv')
cab_data_df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08-01-2016    Pink Cab     ATLANTA GA
# 1             10000012     06-01-2016    Pink Cab     ATLANTA GA
# 2             10000013     02-01-2016    Pink Cab     ATLANTA GA
# 3             10000014     07-01-2016    Pink Cab     ATLANTA GA
# 4             10000015     03-01-2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
cab_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB

# %%
city_data_df = pd.read_csv(datasets_directory + '\City.csv')
city_data_df
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
customer_id_data_df = pd.read_csv(datasets_directory + '\Customer_ID.csv')
customer_id_data_df
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_id_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
transaction_id_data_df = pd.read_csv(datasets_directory + '\Transaction_ID.csv')
transaction_id_data_df
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transaction_id_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %% [markdown]
# ### Hypothesis No 1: Which cab company, has the biggest profit ?

# %% [markdown]
# I create a new column, that has the proft for every transaction

# %%
cab_data_df["Profit"] = cab_data_df["Price Charged"] - cab_data_df["Cost of Trip"]
cab_data_df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08-01-2016    Pink Cab     ATLANTA GA
# 1             10000012     06-01-2016    Pink Cab     ATLANTA GA
# 2             10000013     02-01-2016    Pink Cab     ATLANTA GA
# 3             10000014     07-01-2016    Pink Cab     ATLANTA GA
# 4             10000015     03-01-2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip   Profit
# 0              30.45         370.95      313.6350  57.3150
# 1              28.62         358.52      334.8540  23.6660
# ...

# %% [markdown]
# Then, I create two new data frames for each cab company, one for the Pink cab and another one for the Yellow cab and I calculate the mean and median of the column Profit, in order to understand which one is more profitable

# %%
company_groups = cab_data_df.groupby('Company')

pink_cab_data_df = company_groups.get_group('Pink Cab')
yellow_cab_data_df = company_groups.get_group('Yellow Cab')

# %%
pink_cab_data_df
# Out:
#         Transaction ID Date of Travel   Company           City  KM Travelled  \
# 0             10000011     08-01-2016  Pink Cab     ATLANTA GA         30.45
# 1             10000012     06-01-2016  Pink Cab     ATLANTA GA         28.62
# 2             10000013     02-01-2016  Pink Cab     ATLANTA GA          9.04
# 3             10000014     07-01-2016  Pink Cab     ATLANTA GA         33.17
# 4             10000015     03-01-2016  Pink Cab     ATLANTA GA          8.73
# ...                ...            ...       ...            ...           ...
# 357449        10437610     06-01-2018  Pink Cab  WASHINGTON DC         13.56
# 357450        10437611     31-12-2018  Pink Cab  WASHINGTON DC         29.68
# 357451        10437612     07-01-2018  Pink Cab  WASHINGTON DC         28.50
# 357452        10437614     02-01-2018  Pink Cab  WASHINGTON DC         16.10
# 357453        10437615     05-01-2018  Pink Cab  WASHINGTON DC         22.20
#
#         Price Charged  Cost of Trip  Profit
# ...

# %%
yellow_cab_data_df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 233           10000384     02-01-2016  Yellow Cab     ATLANTA GA
# 234           10000385     09-01-2016  Yellow Cab     ATLANTA GA
# 235           10000386     03-01-2016  Yellow Cab     ATLANTA GA
# 236           10000387     06-01-2016  Yellow Cab     ATLANTA GA
# 237           10000388     07-01-2016  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip    Profit
# 233            33.93        1341.17      464.1624  877.0076
# 234            42.18        1412.06      516.2832  895.7768
# ...

# %%
mean_profit_pink_cab = pink_cab_data_df["Profit"].mean()
median_profit_pink_cab = pink_cab_data_df["Profit"].median()
print("Mean value profit for pink cab: ", mean_profit_pink_cab)
print("Median value profit for pink cab: ", median_profit_pink_cab)
# Out:
# Mean value profit for pink cab:  62.652174109619416
# Median value profit for pink cab:  41.5

# %%
mean_profit_yellow_cab = yellow_cab_data_df["Profit"].mean()
median_profit_yellow_cab = yellow_cab_data_df["Profit"].median()
print("Mean value profit for yellow cab: ", mean_profit_yellow_cab)
print("Median value profit for yellow cab: ", median_profit_yellow_cab)
# Out:
# Mean value profit for yellow cab:  160.25998584102985
# Median value profit for yellow cab:  101.99999999999997

# %% [markdown]
# I visualize the results.

# %%
pink_cab_values = [mean_profit_pink_cab, median_profit_pink_cab]
yellow_cab_values = [mean_profit_yellow_cab, median_profit_yellow_cab]
index = ['Mean Profit', 'Median Profit']
df = pd.DataFrame({'Pink Cab': pink_cab_values, 'Yellow Cab': yellow_cab_values}, index = index)
ax = df.plot.bar(color = ["pink","yellow"], rot = 0)

# %% [markdown]
# Overall, the yellow cab has much more profits than the pink cab.

# %% [markdown]
# ### Hypothesis No 2: In which city, every cab company has bigger profit ?

# %%
every_city_df = pd.merge(cab_data_df[["Company", "City", "Profit"]], city_data_df, on = ["City"], how = 'outer')
every_city_df
# Out:
#            Company              City   Profit Population      Users
# 0         Pink Cab        ATLANTA GA  57.3150   814,885     24,701
# 1         Pink Cab        ATLANTA GA  23.6660   814,885     24,701
# 2         Pink Cab        ATLANTA GA  27.5680   814,885     24,701
# 3         Pink Cab        ATLANTA GA  25.7980   814,885     24,701
# 4         Pink Cab        ATLANTA GA  16.8440   814,885     24,701
# ...            ...               ...      ...        ...        ...
# 359388  Yellow Cab     WASHINGTON DC   6.9020   418,859    127,001
# 359389  Yellow Cab     WASHINGTON DC  87.4200   418,859    127,001
# 359390  Yellow Cab     WASHINGTON DC  32.1420   418,859    127,001
# 359391  Yellow Cab     WASHINGTON DC  13.9608   418,859    127,001
# 359392         NaN  SAN FRANCISCO CA      NaN   629,591    213,609
#
# [359393 rows x 5 columns]

# %% [markdown]
# We drop all the rows where there is NaN, because SAN FRANCISCO CA does not use Pink or Yellow Cab

# %%
every_city_df = every_city_df.dropna()

# %% [markdown]
# I calculate the mean profit for each cab company, for every city and create a new data frame that has this information.

# %%
city_groups = every_city_df.groupby('City')

city_names = []
pink_cab_every_city_mean_profit_values = []
yellow_cab_every_city_mean_profit_values = []
for current_city, current_city_df in city_groups:
    
    current_cab_company_groups = current_city_df.groupby('Company')
    current_pink_cab_mean_profit_value = current_cab_company_groups.get_group('Pink Cab')["Profit"].mean()
    current_yellow_cab_mean_profit_value = current_cab_company_groups.get_group('Yellow Cab')["Profit"].mean()
    
    city_names.append(current_city)
    pink_cab_every_city_mean_profit_values.append(current_pink_cab_mean_profit_value)
    yellow_cab_every_city_mean_profit_values.append(current_yellow_cab_mean_profit_value)
    
every_city_mean_profit_dict = {
    "City": city_names,
    "Pink Cab Mean Profit": pink_cab_every_city_mean_profit_values,
    "Yellow Cab Mean Profit": yellow_cab_every_city_mean_profit_values
}

every_city_mean_profit_df = pd.DataFrame(every_city_mean_profit_dict, index = city_names)
every_city_mean_profit_df
# Out:
#                           City  Pink Cab Mean Profit  Yellow Cab Mean Profit
# ATLANTA GA          ATLANTA GA             54.511961              128.797723
# AUSTIN TX            AUSTIN TX             78.932168              125.249582
# BOSTON MA            BOSTON MA             50.520960               61.483619
# CHICAGO IL          CHICAGO IL             34.047910               64.924486
# DALLAS TX            DALLAS TX             17.920371              195.849415
# DENVER CO            DENVER CO             29.114016              146.853175
# LOS ANGELES CA  LOS ANGELES CA             56.669120              116.656368
# MIAMI FL              MIAMI FL             81.069526              133.872429
# NASHVILLE TN      NASHVILLE TN             34.918269               72.923597
# NEW YORK NY        NEW YORK NY            108.217540              307.864252
# ORANGE COUNTY    ORANGE COUNTY             67.412976              143.785355
# ...

# %% [markdown]
# I visualize the results in a bar plot

# %%
ax = every_city_mean_profit_df.plot.bar(x = "City", title = "Mean Profit for Every City", color = ["pink","yellow"], rot = 0, figsize = (30, 10))

# %% [markdown]
# Conclusions:
# - Except TUCSON AZ city, in every other city, yellow cab company has bigger profits than pink cab company
# - So, most people prefer yellow cab rather than pink cab in almost every city, except TUCSON AZ
# - The city with the bigger profit is New York City, for both companies

# %% [markdown]
# ### Hypothesis No 3: For every cab company, male or female people, use a cab more often ?

# %%
gender_df = pd.merge(customer_id_data_df, transaction_id_data_df, on = ["Customer ID"], how = 'outer')
gender_df = gender_df[["Transaction ID", "Customer ID", "Gender", "Income (USD/Month)"]]
final_gender_df = pd.merge(gender_df, cab_data_df[["Transaction ID", "Company"]], on = ["Transaction ID"], how = 'outer')
final_gender_df = final_gender_df[["Transaction ID", "Customer ID", "Gender", "Company", "Income (USD/Month)"]]
final_gender_df
# Out:
#         Transaction ID  Customer ID  Gender     Company  Income (USD/Month)
# 0             10000011        29290    Male    Pink Cab               10813
# 1             10351127        29290    Male  Yellow Cab               10813
# 2             10412921        29290    Male  Yellow Cab               10813
# 3             10000012        27703    Male    Pink Cab                9237
# 4             10320494        27703    Male  Yellow Cab                9237
# ...                ...          ...     ...         ...                 ...
# 440093        10439799        12490    Male  Yellow Cab               18713
# 440094        10439820        14971    Male         NaN               15346
# 440095        10439838        41414    Male  Yellow Cab                3960
# 440096        10439840        41677    Male  Yellow Cab               19454
# 440097        10439846        39761  Female  Yellow Cab               10128
#
# [440098 rows x 5 columns]

# %% [markdown]
# It is clear that some customers used a cab more than one time.

# %%
final_gender_df = final_gender_df.dropna()
final_gender_df
# Out:
#         Transaction ID  Customer ID  Gender     Company  Income (USD/Month)
# 0             10000011        29290    Male    Pink Cab               10813
# 1             10351127        29290    Male  Yellow Cab               10813
# 2             10412921        29290    Male  Yellow Cab               10813
# 3             10000012        27703    Male    Pink Cab                9237
# 4             10320494        27703    Male  Yellow Cab                9237
# ...                ...          ...     ...         ...                 ...
# 440092        10439790        38520  Female  Yellow Cab               19417
# 440093        10439799        12490    Male  Yellow Cab               18713
# 440095        10439838        41414    Male  Yellow Cab                3960
# 440096        10439840        41677    Male  Yellow Cab               19454
# 440097        10439846        39761  Female  Yellow Cab               10128
#
# [359392 rows x 5 columns]

# %%
company_groups = final_gender_df.groupby('Company')

company_names = []
male_values = []
female_values = []
for current_company, current_company_df in company_groups:
    
    current_gender_groups = current_company_df.groupby('Gender')
    current_male_value = current_gender_groups.get_group('Male').shape[0]
    current_female_value = current_gender_groups.get_group('Female').shape[0]
    
    company_names.append(current_company)
    male_values.append(current_male_value)
    female_values.append(current_female_value)
    
gender_dict = {
    "Company": company_names,
    "Male": male_values,
    "Female": female_values
}

company_gender_df = pd.DataFrame(gender_dict, index = company_names)
company_gender_df
# Out:
#                Company    Male  Female
# Pink Cab      Pink Cab   47231   37480
# Yellow Cab  Yellow Cab  158681  116000

# %%
ax = company_gender_df.plot.bar(x = "Company", color = ["blue","pink"], rot = 0, figsize = (10, 10))

# %% [markdown]
# Based on the bar plot above, we can see that male people tend to use more often a cab than female people.
# Lets see if the above conclusion is logical, based on the mean income a male and a female person has.

# %%
customer_id_data_df
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
income_gender_groups = customer_id_data_df.groupby('Gender')

male_income_mean_value = income_gender_groups.get_group('Male')["Income (USD/Month)"].mean()
female_income_mean_value = income_gender_groups.get_group('Female')["Income (USD/Month)"].mean()

print(male_income_mean_value)
print(female_income_mean_value)
# Out:
# 15040.79545967924
# 14986.068600999602

# %% [markdown]
# The two genders have almost the same mean income, so the reason why men use more a cab than women is not because they make more money and they can afford a cab.

# %% [markdown]
# ### Hypothesis No 4: For every company, which ages use a cab more often ?

# %%
transaction_customer_df = pd.merge(customer_id_data_df[["Customer ID", "Age"]], transaction_id_data_df[["Transaction ID", "Customer ID"]], on = ["Customer ID"], how = 'outer')

transaction_customer_cab_df = pd.merge(cab_data_df[["Transaction ID", "Company", "Profit"]], transaction_customer_df, on = ["Transaction ID"], how = 'outer')
transaction_customer_cab_df
# Out:
#         Transaction ID   Company  Profit  Customer ID  Age
# 0             10000011  Pink Cab  57.315        29290   28
# 1             10000012  Pink Cab  23.666        27703   27
# 2             10000013  Pink Cab  27.568        28712   53
# 3             10000014  Pink Cab  25.798        28020   23
# 4             10000015  Pink Cab  16.844        27182   33
# ...                ...       ...     ...          ...  ...
# 440093        10439406       NaN     NaN        23382   51
# 440094        10439409       NaN     NaN        21420   18
# 440095        10439413       NaN     NaN        49888   23
# 440096        10439418       NaN     NaN        46456   20
# 440097        10439820       NaN     NaN        14971   30
#
# [440098 rows x 5 columns]

# %%
transaction_customer_cab_df = transaction_customer_cab_df.dropna()
transaction_customer_cab_df
# Out:
#         Transaction ID     Company   Profit  Customer ID  Age
# 0             10000011    Pink Cab  57.3150        29290   28
# 1             10000012    Pink Cab  23.6660        27703   27
# 2             10000013    Pink Cab  27.5680        28712   53
# 3             10000014    Pink Cab  25.7980        28020   23
# 4             10000015    Pink Cab  16.8440        27182   33
# ...                ...         ...      ...          ...  ...
# 359387        10440101  Yellow Cab   5.8800        52392   24
# 359388        10440104  Yellow Cab   6.9020        53286   32
# 359389        10440105  Yellow Cab  87.4200        52265   56
# 359390        10440106  Yellow Cab  32.1420        52175   32
# 359391        10440107  Yellow Cab  13.9608        52917   20
#
# [359392 rows x 5 columns]

# %% [markdown]
# First we need to find out the min and the max value from the column Age.

# %%
transaction_customer_cab_df["Age"].describe()
# Out:
# count    359392.000000
# mean         35.336705
# std          12.594234
# min          18.000000
# 25%          25.000000
# 50%          33.000000
# 75%          42.000000
# max          65.000000
# Name: Age, dtype: float64

# %% [markdown]
# As we can see, we have ages from 18 years old to 65 years old. So, we are going to create a new column that is going to be age range.

# %%
# create a list of our conditions
conditions = [
    (transaction_customer_cab_df['Age'] <= 18),
    (transaction_customer_cab_df['Age'] >= 20) & (transaction_customer_cab_df['Age'] <= 29),
    (transaction_customer_cab_df['Age'] >= 30) & (transaction_customer_cab_df['Age'] <= 39),
    (transaction_customer_cab_df['Age'] >= 40) & (transaction_customer_cab_df['Age'] <= 49),
    (transaction_customer_cab_df['Age'] >= 50) & (transaction_customer_cab_df['Age'] <= 59),
    (transaction_customer_cab_df['Age'] >= 60) & (transaction_customer_cab_df['Age'] <= 69),
    ]

# create a list of the values we want to assign for each condition
values = ["10's", "20's", "30's", "40's", "50's", "60's"]

# create a new column and use np.select to assign values to it using our lists as arguments
transaction_customer_cab_df['Age range'] = np.select(conditions, values)

# display updated DataFrame
transaction_customer_cab_df
# Out:
# C:\Users\plust\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#         Transaction ID     Company   Profit  Customer ID  Age Age range
# 0             10000011    Pink Cab  57.3150        29290   28      20's
# 1             10000012    Pink Cab  23.6660        27703   27      20's
# 2             10000013    Pink Cab  27.5680        28712   53      50's
# 3             10000014    Pink Cab  25.7980        28020   23      20's
# 4             10000015    Pink Cab  16.8440        27182   33      30's
# ...                ...         ...      ...          ...  ...       ...
# 359387        10440101  Yellow Cab   5.8800        52392   24      20's
# ...

# %%
company_groups = transaction_customer_cab_df.groupby('Company')

company_names = []
tens_values = []
twenties_values = []
thirties_values = []
fourties_values = []
fifties_values = []
sixties_values = []
for current_company, current_company_df in company_groups:
    
    current_age_range_groups = current_company_df.groupby('Age range')
    current_tens_value = current_age_range_groups.get_group("10's").shape[0]
    current_twenties_value = current_age_range_groups.get_group("20's").shape[0]
    current_thirties_value = current_age_range_groups.get_group("30's").shape[0]
    current_fourties_value = current_age_range_groups.get_group("40's").shape[0]
    current_fifties_value = current_age_range_groups.get_group("50's").shape[0]
    current_sixties_value = current_age_range_groups.get_group("60's").shape[0]
    
    company_names.append(current_company)
    tens_values.append(current_tens_value)
    twenties_values.append(current_twenties_value)
    thirties_values.append(current_thirties_value)
    fourties_values.append(current_fourties_value)
    fifties_values.append(current_fifties_value)
    sixties_values.append(current_sixties_value)
    
age_range_dict = {
    "Company": company_names,
    "10's": tens_values,
    "20's": twenties_values,
    "30's": thirties_values,
    "40's": fourties_values,
    "50's": fifties_values,
    "60's": sixties_values
}

company_age_range_df = pd.DataFrame(age_range_dict, index = company_names)
company_age_range_df
# Out:
#                Company  10's   20's   30's   40's   50's   60's
# Pink Cab      Pink Cab  2676  27470  26408  10931   8976   5429
# Yellow Cab  Yellow Cab  8170  88960  86327  36086  29111  17257

# %%
ax = company_age_range_df.plot.bar(x = "Company", rot = 0, figsize = (10, 10))

# %% [markdown]
# It is obvious that people between 20 and 29 use cab more often than the other ages in both cab companies.

# %% [markdown]
# ### Hypothesis No 5: For every company, which season is considered more profitable?

# %%
cab_data_df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08-01-2016    Pink Cab     ATLANTA GA
# 1             10000012     06-01-2016    Pink Cab     ATLANTA GA
# 2             10000013     02-01-2016    Pink Cab     ATLANTA GA
# 3             10000014     07-01-2016    Pink Cab     ATLANTA GA
# 4             10000015     03-01-2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip   Profit
# 0              30.45         370.95      313.6350  57.3150
# 1              28.62         358.52      334.8540  23.6660
# ...

# %%
winter_list = [12, 1, 2]
spring_list = [3, 4, 5]
summer_list = [6, 7, 8]

# A function that takes as input a date and return the month of the date.
def find_season(a_date):
    temp_list = a_date.split("-")
    month = int(temp_list[1])
    if (month in winter_list):
        return "Winter"
    elif (month in spring_list):
        return "Spring"
    elif (month in summer_list):
        return "Summer"
    else:
        return "Autumn"



cab_data_df["Season"] = cab_data_df['Date of Travel'].apply(find_season)

# %%
cab_data_df
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     08-01-2016    Pink Cab     ATLANTA GA
# 1             10000012     06-01-2016    Pink Cab     ATLANTA GA
# 2             10000013     02-01-2016    Pink Cab     ATLANTA GA
# 3             10000014     07-01-2016    Pink Cab     ATLANTA GA
# 4             10000015     03-01-2016    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     08-01-2018  Yellow Cab  WASHINGTON DC
# 359388        10440104     04-01-2018  Yellow Cab  WASHINGTON DC
# 359389        10440105     05-01-2018  Yellow Cab  WASHINGTON DC
# 359390        10440106     05-01-2018  Yellow Cab  WASHINGTON DC
# 359391        10440107     02-01-2018  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip   Profit  Season
# 0              30.45         370.95      313.6350  57.3150  Winter
# ...

# %%
company_groups = cab_data_df.groupby('Company')

company_names = []
winter_mean_profit_values = []
spring_mean_profit_values = []
summer_mean_profit_values = []
autumn_mean_profit_values = []
for current_company, current_company_df in company_groups:
    
    current_season_groups = current_company_df.groupby('Season')
    current_winter_mean_profit_value = current_season_groups.get_group("Winter")["Profit"].mean()
    current_spring_mean_profit_value = current_season_groups.get_group("Spring")["Profit"].mean()
    current_summer_mean_profit_value = current_season_groups.get_group("Summer")["Profit"].mean()
    current_autumn_mean_profit_value = current_season_groups.get_group("Autumn")["Profit"].mean()
    
    company_names.append(current_company)
    winter_mean_profit_values.append(current_winter_mean_profit_value)
    spring_mean_profit_values.append(current_spring_mean_profit_value)
    summer_mean_profit_values.append(current_summer_mean_profit_value)
    autumn_mean_profit_values.append(current_autumn_mean_profit_value)
    
season_dict = {
    "Company": company_names,
    "Winter": winter_mean_profit_values,
    "Spring": spring_mean_profit_values,
    "Summer": summer_mean_profit_values,
    "Autumn": autumn_mean_profit_values,
}

season_df = pd.DataFrame(season_dict, index = company_names)
season_df
# Out:
#                Company      Winter      Spring      Summer      Autumn
# Pink Cab      Pink Cab   83.487477   53.786264   45.672158   64.060904
# Yellow Cab  Yellow Cab  168.054045  190.793259  146.414056  145.810517

# %%
ax = season_df.plot.bar(x = "Company", rot = 0, figsize = (10, 10))

# %% [markdown]
# We can point out that for the Pink company, winter is more profitable and for the Yellow company Spring is more profitable.

# %% [markdown]
# ### Conclusions
#
# - Generally, Yellow company is more profitable from Pink Company
# - For both companies, New York City is more profitable, but again the profits of Yellow company are much bigger
# - For both companies, men use more often a cab
# - People aged 20 to 29, tend to use a cab more often for both companies
# - For Yellow company, spring is considered the most profitable season, while for Pink company winter. Again the profits of the Yellow company are way bigger than the profits of Pink company, in all seasons
#
# Taking everything into consideration, based on the data above, I encourage the XYZ company to invest in the Yellow cab company.
